# %% [markdown]
# ## Part 1: Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import numpy as np
from tensorflow.keras.models import Model
from tensorflow.keras import layers

#  Import and read the attrition data
attrition_df = pd.read_csv('https://static.bc-edx.com/ai/ail-v-1-0/m19/lms/datasets/attrition.csv')
attrition_df.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   41       Yes      Travel_Rarely                   Sales                 1
# 1   49        No  Travel_Frequently  Research & Development                 8
# 2   37       Yes      Travel_Rarely  Research & Development                 2
# 3   33        No  Travel_Frequently  Research & Development                 3
# 4   27        No      Travel_Rarely  Research & Development                 2
#
#    Education EducationField  EnvironmentSatisfaction  HourlyRate  \
# 0          2  Life Sciences                        2          94
# 1          1  Life Sciences                        3          61
# 2          2          Other                        4          92
# 3          4  Life Sciences                        4          56
# 4          1        Medical                        1          40
#
#    JobInvolvement  ...  PerformanceRating RelationshipSatisfaction  \
# ...

# %%
# Determine the number of unique values in each column
attrition_df.nunique()
# Out:
# Age                         43
# Attrition                    2
# BusinessTravel               3
# Department                   3
# DistanceFromHome            29
# Education                    5
# EducationField               6
# EnvironmentSatisfaction      4
# HourlyRate                  71
# JobInvolvement               4
# JobLevel                     5
# JobRole                      9
# JobSatisfaction              4
# MaritalStatus                3
# NumCompaniesWorked          10
# OverTime                     2
# PercentSalaryHike           15
# PerformanceRating            2
# RelationshipSatisfaction     4
# StockOptionLevel             4
# TotalWorkingYears           40
# TrainingTimesLastYear        7
# WorkLifeBalance              4
# YearsAtCompany              37
# YearsInCurrentRole          19
# YearsSinceLastPromotion     16
# YearsWithCurrManager        18
# dtype: int64

# %%
# Create y_df with the Attrition and Department columns
y_df = attrition_df[['Attrition', 'Department']]

# %%
# Create a list of at least 10 column names to use as X data
X_cols = ['Age', 'OverTime', 'DistanceFromHome', 'Education', 'StockOptionLevel', 'HourlyRate', 'WorkLifeBalance', 'YearsAtCompany', 'JobRole', 'JobSatisfaction']

# Create X_df using your selected columns
X_df = attrition_df[X_cols]

# Show the data types for X_df
X_df.dtypes
# Out:
# Age                  int64
# OverTime            object
# DistanceFromHome     int64
# Education            int64
# StockOptionLevel     int64
# HourlyRate           int64
# WorkLifeBalance      int64
# YearsAtCompany       int64
# JobRole             object
# JobSatisfaction      int64
# dtype: object

# %%
# Split the data into training and testing sets
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_encoded, y_df, random_state=1)

# %%
# Convert your X data to numeric data types however you see fit
# Add new code cells as necessary
X_encoded = pd.get_dummies(X_df, columns=['Age', 'OverTime', 'DistanceFromHome', 'Education', 'StockOptionLevel', 'HourlyRate', 'WorkLifeBalance', 'YearsAtCompany', 'JobRole', 'JobSatisfaction']) # Update with your actual categorical columns

# %%
# Create a StandardScaler
scaler = StandardScaler()

# Fit the StandardScaler to the training data
X_scaler = scaler.fit(X_train)

# Scale the training and testing data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
from sklearn.preprocessing import OneHotEncoder

# Create a OneHotEncoder for the Department column
enc_dept = OneHotEncoder(sparse_output=False, handle_unknown='ignore')
dept_train = enc_dept.fit_transform(y_train[['Department']])
dept_test = enc_dept.transform(y_test[['Department']])

# Fit the encoder to the training data


# Create two new variables by applying the encoder
# to the training and testing data

# %%
# Create a OneHotEncoder for the Attrition column
enc_att = OneHotEncoder(sparse_output=False, handle_unknown='ignore')
att_train = enc_att.fit_transform(y_train[['Attrition']])
att_test = enc_att.transform(y_test[['Attrition']])

# Fit the encoder to the training data


# Create two new variables by applying the encoder
# to the training and testing data

# %% [markdown]
# ## Part 2: Create, Compile, and Train the Model

# %%
# Find the number of columns in the X training data.
number_input_features = X_train_scaled.shape[1]


# Create the input layer
input_data = layers.Input(shape=(number_input_features,))


# Create at least two shared layers
hidden_layer1 = layers.Dense(10, activation='relu')(input_data)
hidden_layer2 = layers.Dense(5, activation='relu')(hidden_layer1)

# %%
# Create a branch for Department
# with a hidden layer and an output layer
dept_hidden = layers.Dense(5, activation='relu')(hidden_layer2)
dept_output = layers.Dense(dept_train.shape[1], activation='softmax', name='department')(dept_hidden)

# %%
# Create a branch for Attrition
# with a hidden layer and an output layer

# Create the hidden layer

# Create the output layer
att_hidden = layers.Dense(5, activation='relu')(hidden_layer2)
att_output = layers.Dense(att_train.shape[1], activation='sigmoid', name='attrition')(att_hidden)

# %%
# Create the model
model = Model(inputs=input_data, outputs=[dept_output, att_output])

# Compile the model
model.compile(optimizer='adam',
              loss={'department': 'categorical_crossentropy', 'attrition': 'binary_crossentropy'},
              metrics={'department': 'accuracy', 'attrition': 'accuracy'})

# Summarize the model
model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 208)            │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 10)             │          2,090 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 5)              │             55 │ dense[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# ...

# %%
# Train the model
model.fit(X_train_scaled, {'department': dept_train, 'attrition': att_train}, epochs=100)
# Out:
# Epoch 1/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - attrition_accuracy: 0.4164 - attrition_loss: 0.7186 - department_accuracy: 0.2588 - department_loss: 1.2271 - loss: 1.9458
# Epoch 2/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - attrition_accuracy: 0.7623 - attrition_loss: 0.6833 - department_accuracy: 0.4899 - department_loss: 1.1043 - loss: 1.7877
# Epoch 3/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attrition_accuracy: 0.8336 - attrition_loss: 0.6611 - department_accuracy: 0.6501 - department_loss: 1.0527 - loss: 1.7139
# Epoch 4/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attrition_accuracy: 0.8544 - attrition_loss: 0.6387 - department_accuracy: 0.6775 - department_loss: 1.0279 - loss: 1.6666
# Epoch 5/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - attrition_accuracy: 0.8423 - attrition_loss: 0.6192 - department_accuracy: 0.7285 - department_loss: 1.0001 - loss: 1.6194
# Epoch 6/100
# ...

# %%
# Evaluate the model with the testing data
loss, dept_loss, att_loss, dept_accuracy, att_accuracy = model.evaluate(X_test_scaled, {'department': dept_test, 'attrition': att_test}, verbose=2)
# Out:
# 12/12 - 1s - 66ms/step - attrition_accuracy: 0.7690 - attrition_loss: 1.3538 - department_accuracy: 0.9158 - department_loss: 0.5600 - loss: 1.9373

# %%
# Print the accuracy for both department and attrition
print(f"Department Accuracy: {dept_accuracy}")
print(f"Attrition Accuracy: {att_accuracy}")
# Out:
# Department Accuracy: 0.76902174949646
# Attrition Accuracy: 0.91576087474823

# %% [markdown]
# # Summary
#
# In the provided space below, briefly answer the following questions.
#
# 1. Is accuracy the best metric to use on this data? Why or why not?
#
# 2. What activation functions did you choose for your output layers, and why?
#
# 3. Can you name a few ways that this model might be improved?

# %% [markdown]
# YOUR ANSWERS HERE
#
# 1. Accuracy might not be the best metric if the classes are imbalanced, if there are significantly more employees who don't leave the company than those who do. In such cases, other metrics like precision, recall, and F1-score might be more informative.
# 2. Department: 'softmax' is used because it's a multi-class classification problem (predicting one of several departments).
#
#   Attrition: 'sigmoid' is used because it's a binary classification problem (predicting whether an employee will leave or stay).
#
# 3. Feature engineering: Create new features or transform existing ones to improve model performance.
#
#   Regularization: Add techniques like dropout or L1/L2 regularization to prevent overfitting.
#
#   Different model architectures: Explore other model types like Random Forest or Gradient Boosting.
#
#   Address class imbalance: If the data is imbalanced, consider techniques like oversampling, undersampling, or using weighted loss functio
